# %%
import pandas as pd

penguins = pd.read_csv("../datasets/penguins.csv")

columns = ["Body Mass (g)", "Flipper Length (mm)", "Culmen Length (mm)"]
target_name = "Species"

# Remove lines with missing values for the columns of interestes
penguins_non_missing = penguins[columns + [target_name]].dropna()

data = penguins_non_missing[columns]
target = penguins_non_missing[target_name]

# %% [markdown]
# ## Question 1

# %%
target.value_counts()
# Out:
# Adelie Penguin (Pygoscelis adeliae)          151
# Gentoo penguin (Pygoscelis papua)            123
# Chinstrap penguin (Pygoscelis antarctica)     68
# Name: Species, dtype: int64

# %%
data.min()
# Out:
# Body Mass (g)          2700.0
# Flipper Length (mm)     172.0
# Culmen Length (mm)       32.1
# dtype: float64

# %%
data.max()
# Out:
# Body Mass (g)          6300.0
# Flipper Length (mm)     231.0
# Culmen Length (mm)       59.6
# dtype: float64

# %% [markdown]
# ## Question 2

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
model = Pipeline(steps=[
    ("preprocessor", StandardScaler()),
    ("classifier", KNeighborsClassifier(n_neighbors=5)),
])

# %%
from sklearn.model_selection import cross_validate

res = cross_validate(model, data, target, scoring='balanced_accuracy')
res['test_score'].mean(), res['test_score'].std()
# Out:
# (0.9487175942337233, 0.01917307908775349)

# %%
model51 = Pipeline(steps=[
    ("preprocessor", StandardScaler()),
    ("classifier", KNeighborsClassifier(n_neighbors=51)),
])

res = cross_validate(model51, data, target, scoring='balanced_accuracy')
res['test_score'].mean()
# Out:
# 0.9393601953601953

# %%
model2 = Pipeline(steps=[
    ("classifier", KNeighborsClassifier(n_neighbors=5)),
])

res = cross_validate(model2, data, target, scoring='balanced_accuracy')
res['test_score'].mean(), res['test_score'].std()
# Out:
# (0.7215834416479577, 0.09837706199533194)

# %% [markdown]
# ## Question 3

# %%
from sklearn.model_selection import train_test_split

data_train, data_test, target_train, target_test = train_test_split(
    data, target, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import PowerTransformer


all_preprocessors = [
    None,
    StandardScaler(),
    MinMaxScaler(),
    QuantileTransformer(n_quantiles=100),
    PowerTransformer(method="box-cox"),
]

n_neighbors = [5, 51, 101]

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'preprocessor': all_preprocessors,
    'classifier__n_neighbors': n_neighbors
}

model_gs = GridSearchCV(model, param_grid=param_grid)

# %%
model_gs.fit(data_train, target_train)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('preprocessor', StandardScaler()),
#                                        ('classifier', KNeighborsClassifier())]),
#              param_grid={'classifier__n_neighbors': [5, 51, 101],
#                          'preprocessor': [None, StandardScaler(),
#                                           MinMaxScaler(),
#                                           QuantileTransformer(n_quantiles=100),
#                                           PowerTransformer(method='box-cox')]})

# %%
model_gs.cv_results_
# Out:
# {'mean_fit_time': array([0.00189872, 0.0028986 , 0.00271564, 0.00335164, 0.00563011,
#         0.0017312 , 0.00287766, 0.0027153 , 0.00333047, 0.00561948,
#         0.00188813, 0.00294924, 0.00280471, 0.00345058, 0.00564713]),
#  'std_fit_time': array([2.50370905e-04, 2.88333143e-05, 9.33115616e-06, 2.71865769e-05,
#         3.50269484e-04, 8.44957597e-07, 4.48139162e-05, 7.28703288e-06,
#         1.41026151e-05, 3.15202866e-04, 2.42858862e-04, 3.21810329e-05,
#         1.79219739e-05, 4.30983773e-05, 3.57254959e-04]),
#  'mean_score_time': array([0.00258398, 0.00259295, 0.00255866, 0.00271845, 0.0026854 ,
#         0.00271268, 0.00283175, 0.00284185, 0.00295868, 0.00295935,
#         0.00372419, 0.00316706, 0.00314837, 0.00330663, 0.00322132]),
#  'std_score_time': array([1.01489275e-04, 2.49990038e-05, 5.06301374e-06, 3.61985049e-05,
#         1.76806949e-05, 2.27793450e-05, 1.69249653e-05, 3.24713851e-05,
#         2.63737076e-05, 2.33239182e-05, 1.30634572e-03, 1.67108125e-05,
#         3.15287816e-05, 4.08304608e-05, 3.79370037e-05]),
#  'param_classifier__n_neighbors': masked_array(data=[5, 5, 5, 5, 5, 51, 51, 51, 51, 51, 101, 101, 101, 101,
#                     101],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_preprocessor': masked_array(data=[None, StandardScaler(), MinMaxScaler(),
#                     QuantileTransformer(n_quantiles=100),
#                     PowerTransformer(method='box-cox'), None,
#                     StandardScaler(), MinMaxScaler(),
#                     QuantileTransformer(n_quantiles=100),
#                     PowerTransformer(method='box-cox'), None,
#                     StandardScaler(), MinMaxScaler(),
#                     QuantileTransformer(n_quantiles=100),
#                     PowerTransformer(method='box-cox')],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'classifier__n_neighbors': 5, 'preprocessor': None},
#   {'classifier__n_neighbors': 5, 'preprocessor': StandardScaler()},
#   {'classifier__n_neighbors': 5, 'preprocessor': MinMaxScaler()},
#   {'classifier__n_neighbors': 5,
#    'preprocessor': QuantileTransformer(n_quantiles=100)},
#   {'classifier__n_neighbors': 5,
#    'preprocessor': PowerTransformer(method='box-cox')},
#   {'classifier__n_neighbors': 51, 'preprocessor': None},
#   {'classifier__n_neighbors': 51, 'preprocessor': StandardScaler()},
#   {'classifier__n_neighbors': 51, 'preprocessor': MinMaxScaler()},
#   {'classifier__n_neighbors': 51,
#    'preprocessor': QuantileTransformer(n_quantiles=100)},
#   {'classifier__n_neighbors': 51,
#    'preprocessor': PowerTransformer(method='box-cox')},
#   {'classifier__n_neighbors': 101, 'preprocessor': None},
#   {'classifier__n_neighbors': 101, 'preprocessor': StandardScaler()},
#   {'classifier__n_neighbors': 101, 'preprocessor': MinMaxScaler()},
#   {'classifier__n_neighbors': 101,
#    'preprocessor': QuantileTransformer(n_quantiles=100)},
#   {'classifier__n_neighbors': 101,
#    'preprocessor': PowerTransformer(method='box-cox')}],
#  'split0_test_score': array([0.75      , 0.98076923, 0.98076923, 0.98076923, 0.98076923,
#         0.67307692, 0.96153846, 0.98076923, 0.94230769, 0.94230769,
#         0.69230769, 0.86538462, 0.86538462, 0.82692308, 0.84615385]),
#  'split1_test_score': array([0.70588235, 0.98039216, 0.98039216, 0.96078431, 0.98039216,
#         0.74509804, 0.98039216, 0.98039216, 0.94117647, 0.98039216,
#         0.74509804, 0.88235294, 0.8627451 , 0.84313725, 0.88235294]),
#  'split2_test_score': array([0.80392157, 0.96078431, 0.96078431, 0.94117647, 0.96078431,
#         0.7254902 , 0.92156863, 0.90196078, 0.90196078, 0.88235294,
#         0.7254902 , 0.78431373, 0.78431373, 0.80392157, 0.78431373]),
#  'split3_test_score': array([0.76470588, 0.94117647, 0.96078431, 0.90196078, 0.96078431,
#         0.78431373, 0.94117647, 0.94117647, 0.92156863, 0.94117647,
#         0.78431373, 0.8627451 , 0.84313725, 0.80392157, 0.8627451 ]),
#  'split4_test_score': array([0.78431373, 0.94117647, 0.96078431, 0.94117647, 0.94117647,
#         0.74509804, 0.90196078, 0.94117647, 0.90196078, 0.94117647,
#         0.74509804, 0.8627451 , 0.82352941, 0.82352941, 0.84313725]),
#  'mean_test_score': array([0.76176471, 0.96085973, 0.96870287, 0.94517345, 0.9647813 ,
#         0.73461538, 0.9413273 , 0.94909502, 0.92179487, 0.93748115,
#         0.73846154, 0.8515083 , 0.83582202, 0.82028658, 0.84374057]),
#  'std_test_score': array([0.03333333, 0.01762255, 0.00969894, 0.0261153 , 0.01475434,
#         0.0362214 , 0.02783776, 0.02942723, 0.01779469, 0.03140408,
#         0.02996312, 0.03438484, 0.02985473, 0.01491536, 0.03283238]),
#  'rank_test_score': array([13,  3,  1,  5,  2, 15,  6,  4,  8,  7, 14,  9, 11, 12, 10],
#        dtype=int32)}

# %%
pd.DataFrame(model_gs.cv_results_).sort_values('rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 2        0.002716  9.331156e-06         0.002559        0.000005
# 4        0.005630  3.502695e-04         0.002685        0.000018
# 1        0.002899  2.883331e-05         0.002593        0.000025
# 7        0.002715  7.287033e-06         0.002842        0.000032
# 3        0.003352  2.718658e-05         0.002718        0.000036
# 6        0.002878  4.481392e-05         0.002832        0.000017
# 9        0.005619  3.152029e-04         0.002959        0.000023
# 8        0.003330  1.410262e-05         0.002959        0.000026
# 11       0.002949  3.218103e-05         0.003167        0.000017
# 14       0.005647  3.572550e-04         0.003221        0.000038
# 12       0.002805  1.792197e-05         0.003148        0.000032
# 13       0.003451  4.309838e-05         0.003307        0.000041
# 0        0.001899  2.503709e-04         0.002584        0.000101
# 10       0.001888  2.428589e-04         0.003724        0.001306
# 5        0.001731  8.449576e-07         0.002713        0.000023
#
#    param_classifier__n_neighbors                    param_preprocessor  \
# 2                              5                        MinMaxScaler()
# 4                              5    PowerTransformer(method='box-cox')
# 1                              5                      StandardScaler()
# 7                             51                        MinMaxScaler()
# 3                              5  QuantileTransformer(n_quantiles=100)
# 6                             51                      StandardScaler()
# 9                             51    PowerTransformer(method='box-cox')
# 8                             51  QuantileTransformer(n_quantiles=100)
# 11                           101                      StandardScaler()
# 14                           101    PowerTransformer(method='box-cox')
# 12                           101                        MinMaxScaler()
# 13                           101  QuantileTransformer(n_quantiles=100)
# 0                              5                                  None
# 10                           101                                  None
# 5                             51                                  None
#
#                                                params  split0_test_score  \
# 2   {'classifier__n_neighbors': 5, 'preprocessor':...           0.980769
# 4   {'classifier__n_neighbors': 5, 'preprocessor':...           0.980769
# 1   {'classifier__n_neighbors': 5, 'preprocessor':...           0.980769
# 7   {'classifier__n_neighbors': 51, 'preprocessor'...           0.980769
# 3   {'classifier__n_neighbors': 5, 'preprocessor':...           0.980769
# 6   {'classifier__n_neighbors': 51, 'preprocessor'...           0.961538
# 9   {'classifier__n_neighbors': 51, 'preprocessor'...           0.942308
# 8   {'classifier__n_neighbors': 51, 'preprocessor'...           0.942308
# 11  {'classifier__n_neighbors': 101, 'preprocessor...           0.865385
# 14  {'classifier__n_neighbors': 101, 'preprocessor...           0.846154
# 12  {'classifier__n_neighbors': 101, 'preprocessor...           0.865385
# 13  {'classifier__n_neighbors': 101, 'preprocessor...           0.826923
# 0   {'classifier__n_neighbors': 5, 'preprocessor':...           0.750000
# 10  {'classifier__n_neighbors': 101, 'preprocessor...           0.692308
# 5   {'classifier__n_neighbors': 51, 'preprocessor'...           0.673077
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 2            0.980392           0.960784           0.960784
# 4            0.980392           0.960784           0.960784
# 1            0.980392           0.960784           0.941176
# 7            0.980392           0.901961           0.941176
# 3            0.960784           0.941176           0.901961
# 6            0.980392           0.921569           0.941176
# 9            0.980392           0.882353           0.941176
# 8            0.941176           0.901961           0.921569
# 11           0.882353           0.784314           0.862745
# 14           0.882353           0.784314           0.862745
# 12           0.862745           0.784314           0.843137
# 13           0.843137           0.803922           0.803922
# 0            0.705882           0.803922           0.764706
# 10           0.745098           0.725490           0.784314
# 5            0.745098           0.725490           0.784314
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 2            0.960784         0.968703        0.009699                1
# 4            0.941176         0.964781        0.014754                2
# 1            0.941176         0.960860        0.017623                3
# 7            0.941176         0.949095        0.029427                4
# 3            0.941176         0.945173        0.026115                5
# 6            0.901961         0.941327        0.027838                6
# 9            0.941176         0.937481        0.031404                7
# 8            0.901961         0.921795        0.017795                8
# 11           0.862745         0.851508        0.034385                9
# 14           0.843137         0.843741        0.032832               10
# 12           0.823529         0.835822        0.029855               11
# 13           0.823529         0.820287        0.014915               12
# 0            0.784314         0.761765        0.033333               13
# 10           0.745098         0.738462        0.029963               14
# 5            0.745098         0.734615        0.036221               15
