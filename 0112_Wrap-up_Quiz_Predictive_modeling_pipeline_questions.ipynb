# %%
import pandas as pd
ames_housing = pd.read_csv("../datasets/house_prices.csv", na_values="?")
ames_housing = ames_housing.drop(columns="Id")

# %% [markdown]
# # Question 1

# %%
ames_housing.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 1         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 2         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 3         Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 4         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0       0      2    2008        WD         Normal     208500
# ...

# %%
ames_housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
target_name = "SalePrice"
data, target = ames_housing.drop(columns=target_name), ames_housing[target_name]
target = (target > 200_000).astype(int)

# %% [markdown]
# # Question 2

# %%
data.head(20)
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0           60       RL         65.0     8450   Pave   NaN      Reg
# 1           20       RL         80.0     9600   Pave   NaN      Reg
# 2           60       RL         68.0    11250   Pave   NaN      IR1
# 3           70       RL         60.0     9550   Pave   NaN      IR1
# 4           60       RL         84.0    14260   Pave   NaN      IR1
# 5           50       RL         85.0    14115   Pave   NaN      IR1
# 6           20       RL         75.0    10084   Pave   NaN      Reg
# 7           60       RL          NaN    10382   Pave   NaN      IR1
# 8           50       RM         51.0     6120   Pave   NaN      Reg
# 9          190       RL         50.0     7420   Pave   NaN      Reg
# 10          20       RL         70.0    11200   Pave   NaN      Reg
# 11          60       RL         85.0    11924   Pave   NaN      IR1
# 12          20       RL          NaN    12968   Pave   NaN      IR2
# ...

# %%
data.dtypes
# Out:
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
#                   ...
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# Length: 79, dtype: object

# %%
data['Alley'].value_counts()
# Out:
# Grvl    50
# Pave    41
# Name: Alley, dtype: int64

# %% [markdown]
# # Question 3

# %%
from sklearn.compose import make_column_selector as selector

numerical_columns_selector = selector(dtype_exclude=object)
categorical_columns_selector = selector(dtype_include=object)

numerical_columns = numerical_columns_selector(data)
categorical_columns = categorical_columns_selector(data)

# %%
numerical_columns
# Out:
# ['MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold']

# %% [markdown]
# data[numerical_columns]

# %%
len(numerical_columns)
# Out:
# 36

# %% [markdown]
# # Question 4

# %%
data['LotFrontage'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
data['LotArea'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
data['OverallQual'].value_counts()
# Out:
# 5     397
# 6     374
# 7     319
# 8     168
# 4     116
# 9      43
# 3      20
# 10     18
# 2       3
# 1       2
# Name: OverallQual, dtype: int64

# %%
data['OverallCond'].value_counts()
# Out:
# 5    821
# 6    252
# 7    205
# 8     72
# 4     57
# 3     25
# 9     22
# 2      5
# 1      1
# Name: OverallCond, dtype: int64

# %%
data['YearBuilt'].value_counts()
# Out:
# 2006    67
# 2005    64
# 2004    54
# 2007    49
# 2003    45
#         ..
# 1904     1
# 1898     1
# 1893     1
# 1882     1
# 2010     1
# Name: YearBuilt, Length: 112, dtype: int64

# %%
data['YearBuilt'].hist(bins=112)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Question 5

# %%
numerical_features = [
  "LotFrontage", "LotArea", "MasVnrArea", "BsmtFinSF1", "BsmtFinSF2",
  "BsmtUnfSF", "TotalBsmtSF", "1stFlrSF", "2ndFlrSF", "LowQualFinSF",
  "GrLivArea", "BedroomAbvGr", "KitchenAbvGr", "TotRmsAbvGrd", "Fireplaces",
  "GarageCars", "GarageArea", "WoodDeckSF", "OpenPorchSF", "EnclosedPorch",
  "3SsnPorch", "ScreenPorch", "PoolArea", "MiscVal",
]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# %%
numerical_pipeline = make_pipeline(StandardScaler(), SimpleImputer(strategy="mean"), LogisticRegression())

# %%
from sklearn.model_selection import cross_validate

data_numerical = data[numerical_features]
cv = cross_validate(numerical_pipeline, data_numerical, target)

# %%
ts = cv['test_score']
ts.mean(), ts.std()
# Out:
# (0.8952054794520548, 0.010958904109589053)

# %% [markdown]
# # Question 6

# %%
data_categorical = data.drop(numerical_features, axis=1)

# %%
# data_categorical.columns.values.tolist()

# %%
data_categorical.head()
# Out:
#    MSSubClass MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# 0          60       RL   Pave   NaN      Reg         Lvl    AllPub    Inside
# 1          20       RL   Pave   NaN      Reg         Lvl    AllPub       FR2
# 2          60       RL   Pave   NaN      IR1         Lvl    AllPub    Inside
# 3          70       RL   Pave   NaN      IR1         Lvl    AllPub    Corner
# 4          60       RL   Pave   NaN      IR1         Lvl    AllPub       FR2
#
#   LandSlope Neighborhood  ... GarageQual GarageCond PavedDrive PoolQC  Fence  \
# 0       Gtl      CollgCr  ...         TA         TA          Y    NaN    NaN
# 1       Gtl      Veenker  ...         TA         TA          Y    NaN    NaN
# 2       Gtl      CollgCr  ...         TA         TA          Y    NaN    NaN
# 3       Gtl      Crawfor  ...         TA         TA          Y    NaN    NaN
# 4       Gtl      NoRidge  ...         TA         TA          Y    NaN    NaN
#
# ...

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
num_pipeline = make_pipeline(
                    StandardScaler(), 
                    SimpleImputer(strategy='mean'))

cat_pipeline = make_pipeline(
                    SimpleImputer(strategy='most_frequent'), 
                    OneHotEncoder(handle_unknown='ignore'))

# %%
from sklearn.compose import ColumnTransformer
num_cols = numerical_features
cat_cols = data.columns.difference(num_cols)
preproc = ColumnTransformer([('num', num_pipeline, num_cols), ('cat', cat_pipeline, cat_cols)])

# %%
data_categorical.columns.values.tolist()[:6]
# Out:
# ['MSSubClass', 'MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour']

# %%
data['LandContour'].value_counts()
# Out:
# Lvl    1311
# Bnk      63
# HLS      50
# Low      36
# Name: LandContour, dtype: int64

# %%
model = make_pipeline(preproc, LogisticRegression(max_iter=500))

# %%
from sklearn import set_config
set_config(display='diagram')
model
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('standardscaler',
#                                                                    StandardScaler()),
#                                                                   ('simpleimputer',
#                                                                    SimpleImputer())]),
#                                                   ['LotFrontage', 'LotArea',
#                                                    'MasVnrArea', 'BsmtFinSF1',
#                                                    'BsmtFinSF2', 'BsmtUnfSF',
#                                                    'TotalBsmtSF', '1stFlrSF',
#                                                    '2ndFlrSF', 'LowQualFinSF',
#                                                    'GrLivArea', 'BedroomAbvGr',
# ...

# %%
# https://scikit-learn.org/stable/auto_examples/compose/plot_column_transformer_mixed_types.html
cv = cross_validate(model, data, target, cv=5)

# %%
ts = cv['test_score']
ts.mean(), ts.std()
# Out:
# (0.9191780821917808, 0.009589041095890413)
